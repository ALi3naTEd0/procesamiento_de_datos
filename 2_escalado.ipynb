# %% [markdown]
# # Escalado
# Conjunto de datos: iris (incluido en sklearn)
# Este conjunto de datos es compacto y perfecto para demostrar técnicas de escalado.

# %%
# Importar librerías necesarias
from sklearn.datasets import load_iris
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Cargar el conjunto de datos
iris = load_iris(as_frame=True)
data = iris.data

# %%
# Visualizar las estadísticas iniciales
print("Estadísticas iniciales:")
data.describe()
# Out:
# Estadísticas iniciales:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
# Aplicar MinMaxScaler
minmax_scaler = MinMaxScaler()
data_minmax = pd.DataFrame(minmax_scaler.fit_transform(data), columns=data.columns)

# %%
# Aplicar StandardScaler
standard_scaler = StandardScaler()
data_standard = pd.DataFrame(standard_scaler.fit_transform(data), columns=data.columns)

# %% [markdown]
# # Ejercicios
# Contesta las siguientes preguntas. Para cada pregunta, deberás escribir código que demostrará cómo llegaste al resultado. Crea gráficas en donde veas correcto.

# %% [markdown]
# ### 1. ¿Qué diferencias encuentras entre las estadísticas originales y las del escalado MinMax?

# %%
print("=== Estadísticas originales ===")
print(data.describe().round(4))

print("\n=== Estadísticas después de MinMaxScaler ===")
print(data_minmax.describe().round(4))
# Out:
# === Estadísticas originales ===
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count           150.0000          150.0000           150.0000
# mean              5.8433            3.0573             3.7580
# std               0.8281            0.4359             1.7653
# min               4.3000            2.0000             1.0000
# 25%               5.1000            2.8000             1.6000
# 50%               5.8000            3.0000             4.3500
# 75%               6.4000            3.3000             5.1000
# max               7.9000            4.4000             6.9000
#
#        petal width (cm)
# count          150.0000
# mean             1.1993
# std              0.7622
# min              0.1000
# 25%              0.3000
# 50%              1.3000
# 75%              1.8000
# max              2.5000
#
# === Estadísticas después de MinMaxScaler ===
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# ...

# %% [markdown]
# ### 2. Crea una gráfica de la distribución de la variable 'sepal length (cm)' antes y después del escalado.

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4), sharey=True)

axes[0].hist(data['sepal length (cm)'], bins=20, color='steelblue')
axes[0].set_title('Original')
axes[0].set_xlabel('sepal length (cm)')
axes[0].set_ylabel('Frecuencia')

axes[1].hist(data_minmax['sepal length (cm)'], bins=20, color='salmon')
axes[1].set_title('MinMaxScaler (0–1)')
axes[1].set_xlabel('sepal length (cm)')

axes[2].hist(data_standard['sepal length (cm)'], bins=20, color='mediumseagreen')
axes[2].set_title('StandardScaler (media=0, std=1)')
axes[2].set_xlabel('sepal length (cm)')

plt.suptitle("Distribución de 'sepal length (cm)' antes y después del escalado")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Crea una gráfica de dispersión entre 'sepal length (cm)' y 'sepal width (cm)' con los datos escalados por StandardScaler.

# %%
plt.figure(figsize=(6, 5))
plt.scatter(
    data_standard['sepal length (cm)'],
    data_standard['sepal width (cm)'],
    alpha=0.6, color='steelblue', edgecolors='white', linewidths=0.5
)
plt.title("Dispersión: sepal length vs sepal width\n(StandardScaler)")
plt.xlabel('sepal length (cm) — escalado')
plt.ylabel('sepal width (cm) — escalado')
plt.axhline(0, color='gray', linewidth=0.7, linestyle='--')
plt.axvline(0, color='gray', linewidth=0.7, linestyle='--')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. ¿Qué técnica de escalado crees que es más adecuada para este conjunto de datos? ¿Por qué?

# %%
print("""
StandardScaler es más adecuado para el dataset Iris porque:

1. Las variables no tienen una distribución uniforme acotada; 
   presentan variaciones y algunos valores atípicos leves.

2. StandardScaler preserva mejor la estructura estadística 
   (media=0, std=1), lo que es ideal para algoritmos como 
   PCA, SVM o regresión logística que asumen datos centrados.

3. MinMaxScaler es sensible a outliers: un valor extremo 
   comprime el resto de los datos hacia un rango pequeño.
   Con Iris esto no es crítico, pero StandardScaler sigue 
   siendo la opción más robusta y general.
""")
# Out:
# StandardScaler es más adecuado para el dataset Iris porque:
#
# 1. Las variables no tienen una distribución uniforme acotada;
#    presentan variaciones y algunos valores atípicos leves.
#
# 2. StandardScaler preserva mejor la estructura estadística
#    (media=0, std=1), lo que es ideal para algoritmos como
#    PCA, SVM o regresión logística que asumen datos centrados.
#
# 3. MinMaxScaler es sensible a outliers: un valor extremo
#    comprime el resto de los datos hacia un rango pequeño.
#    Con Iris esto no es crítico, pero StandardScaler sigue
#    siendo la opción más robusta y general.
